# %%
import matplotlib.pyplot as plt
from asas import Asas 

asas_id = '060635+2619.8'

# %%
skymap, lightcurve = Asas.get_images(asas_id)

imgplot = plt.imshow(skymap)
plt.axis('off')

plt.show()


imgplot = plt.imshow(lightcurve)
plt.axis('off')
plt.show()

# %%
lc_table = Asas.get_lightcurve()
print(lc_table)
# Out:
# hi
# None
